# %%
using TaskGraphs
using DataFrames, CSV, Query, Statistics
using PGFPlots
using TikzPictures
tikzCommand("pdflatex")

# %%
data_path = joinpath(dirname(pathof(TaskGraphs)),"..","test","profiling")
# Out:
# "/home/kylebrown/.julia/dev/TaskGraphs/src/../test/profiling"

# %%
filename = joinpath(data_path, "MILP_profiling.csv")
df = CSV.read(filename);

# %%
N = sort(collect(Set{Int}(df[:N])))
M = sort(collect(Set{Int}(df[:M])))
max_parents = sort(collect(Set{Int}(df[:max_parents])))
depth_bias = sort(collect(Set(df[:depth_bias])))
# termination_status = sort(collect(Set{Int}(df[:termination_status])));

# %%
ax = Axis(xlabel="Num Tasks", ylabel="Computation Time (s)", title="My Title", 
    width="20cm", height="12cm")
for (mp,linecolor) in zip(max_parents,["red","blue","black"])
    for (db,linestyle) in zip(depth_bias,["solid","dashed","dash dot","dotted"])
        for (n,mark) in zip(N,["x","square","triangle","circle","diamond"])
            q0 = df |>
                @filter(_.N == n) |>
                @filter(_.max_parents == mp) |> 
                @filter(_.depth_bias == db) |>
                DataFrame
            q1 = q0 |>
                @groupby(_.M) |>
                @map({M=key(_), solve_time=mean(_.solve_time)}) |>
                DataFrame
            push!(ax, 
                Plots.Linear(
                    Vector{Int}(q1.M), 
                    Vector{Float64}(q1.solve_time), 
                    mark=mark,
                    style=string("mark options={style=solid, fill=",linecolor,"}, ",linecolor,",",linestyle,),
#                     onlyMarks=true,
                    # legendentry=string("n = ",n)
                )
            )
        end
    end
end
ax
# Out:
# Axis(PGFPlots.Plots.Plot[Linear(Real[5.0 10.0 20.0 30.0; 0.00330639 0.00688537 0.0304043 0.219362], "x", nothing, "mark options={style=solid, fill=red}, red,solid", nothing, nothing, nothing), Linear(Real[10.0 20.0 40.0 60.0; 0.00962567 0.0258643 0.131399 1.39421], "square", nothing, "mark options={style=solid, fill=red}, red,solid", nothing, nothing, nothing), Linear(Real[20.0 40.0 80.0 120.0; 0.0328524 0.1276 0.625302 5.93689], "triangle", nothing, "mark options={style=solid, fill=red}, red,solid", nothing, nothing, nothing), Linear(Real[50.0 100.0 200.0 300.0; 0.258452 1.43666 11.1918 12.3002], "circle", nothing, "mark options={style=solid, fill=red}, red,solid", nothing, nothing, nothing), Linear(Real[100.0 200.0; 1.67469 8.21399], "diamond", nothing, "mark options={style=solid, fill=red}, red,solid", nothing, nothing, nothing), Linear(Real[5.0 10.0 20.0 30.0; 0.00388225 0.00867931 0.0344747 1.69418], "x", nothing, "mark options={style=solid, fill=red}, red,dashed", nothing, nothing, nothing), Linear(Real[10.0 20.0 40.0 60.0; 0.00938074 0.0356057 0.145877 0.449606], "square", nothing, "mark options={style=solid, fill=red}, red,dashed", nothing, nothing, nothing), Linear(Real[20.0 40.0 80.0 120.0; 0.043398 0.121858 0.952092 8.12107], "triangle", nothing, "mark options={style=solid, fill=red}, red,dashed", nothing, nothing, nothing), Linear(Real[50.0 100.0 200.0 300.0; 0.28829 1.21328 11.057 12.2422], "circle", nothing, "mark options={style=solid, fill=red}, red,dashed", nothing, nothing, nothing), Linear(Real[100.0 200.0; 1.68984 8.73977], "diamond", nothing, "mark options={style=solid, fill=red}, red,dashed", nothing, nothing, nothing)  …  Linear(Real[5.0 10.0 20.0 30.0; 0.00480461 0.00790238 1.42004 6.72066], "x", nothing, "mark options={style=solid, fill=black}, black,dash dot", nothing, nothing, nothing), Linear(Real[10.0 20.0 40.0 60.0; 0.0101714 0.038307 1.05646 10.0336], "square", nothing, "mark options={style=solid, fill=black}, black,dash dot", nothing, nothing, nothing), Linear(Real[20.0 40.0 80.0 120.0; 0.0354227 0.167289 2.49364 8.04774], "triangle", nothing, "mark options={style=solid, fill=black}, black,dash dot", nothing, nothing, nothing), Linear(Real[50.0 100.0 200.0 300.0; 0.35333 2.10273 11.0817 12.2382], "circle", nothing, "mark options={style=solid, fill=black}, black,dash dot", nothing, nothing, nothing), Linear(Real[100.0 200.0; 1.9614 7.1998], "diamond", nothing, "mark options={style=solid, fill=black}, black,dash dot", nothing, nothing, nothing), Linear(Real[5.0 10.0 20.0 30.0; 0.00408697 0.0136681 1.13697 10.0137], "x", nothing, "mark options={style=solid, fill=black}, black,dotted", nothing, nothing, nothing), Linear(Real[10.0 20.0 40.0 60.0; 0.010287 0.0306124 1.02723 10.0417], "square", nothing, "mark options={style=solid, fill=black}, black,dotted", nothing, nothing, nothing), Linear(Real[20.0 40.0 80.0 120.0; 0.038334 0.139361 2.20986 10.2381], "triangle", nothing, "mark options={style=solid, fill=black}, black,dotted", nothing, nothing, nothing), Linear(Real[50.0 100.0 200.0 300.0; 0.339729 2.07325 11.0995 11.9653], "circle", nothing, "mark options={style=solid, fill=black}, black,dotted", nothing, nothing, nothing), Linear(Real[100.0 200.0; 1.78681 8.67194], "diamond", nothing, "mark options={style=solid, fill=black}, black,dotted", nothing, nothing, nothing)], "My Title", "Num Tasks", nothing, "Computation Time (s)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, "20cm", "12cm", nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, "axis")
