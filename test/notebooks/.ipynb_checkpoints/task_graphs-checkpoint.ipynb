# %% [markdown]
# # Task Graphs Problem Formulation

# %%
using LightGraphs, MetaGraphs
using Parameters
using LinearAlgebra
using Compose
using Colors
using TaskGraphs
using GraphPlottingBFS
using DataStructures
using JuMP, MathOptInterface
# using GLPK
using Gurobi
# Out:
# ┌ Info: Recompiling stale cache file /home/kylebrown/.julia/compiled/v1.0/TaskGraphs/apcwx.ji for TaskGraphs [6635cb54-791c-11e9-2805-8512ad3937f9]
# └ @ Base loading.jl:1190
# WARNING: Method definition (::Type{Int64})() in module TaskGraphs at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:64 overwritten at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:66.
# WARNING: Method definition (::Type{Int64})() in module TaskGraphs at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:66 overwritten at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:68.
# WARNING: Method definition (::Type{Int64})() in module TaskGraphs at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:68 overwritten at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:70.
# WARNING: Method definition (::Type{Int64})() in module TaskGraphs at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:70 overwritten at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:72.
# WARNING: Method definition (::Type{Int64})() in module TaskGraphs at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:72 overwritten at /home/kylebrown/.julia/dev/TaskGraphs/src/TaskGraphs.jl:74.

# %%
function GraphPlottingBFS.leaf_case!(G,v,s::BFS_state)
    set_prop!(G,v,:height, 0)   # distance to leaf
    set_prop!(G,v,:depth, s.d) # distance to root
    set_prop!(G,v,:left,  s.w)
    set_prop!(G,v,:width, 1)
    set_prop!(G,v,:right, s.w+1)
    set_prop!(G,v,:center, (get_prop(G,v,:left)+get_prop(G,v,:right))/2.0)
    s = BFS_state(d=s.d,w=s.w+1,d_max=max(s.d_max,s.d))
end
function GraphPlottingBFS.initial_branch_case!(G,v,s::BFS_state)
    set_prop!(G,v,:height, 0)   # distance to leaf
    set_prop!(G,v,:left,  s.w)
    set_prop!(G,v,:depth,  s.d)
    set_prop!(G,v,:edge_count,  0)
    set_prop!(G,v,:center, 0.0)
end
function GraphPlottingBFS.backup!(G,v,v2,s::BFS_state)
    set_prop!(G,v,:height, max(get_prop(G,v,:height),1+get_prop(G,v2,:height)))   # distance to leaf
    set_prop!(G,v,:right, s.w)
    set_prop!(G,v,:width, s.w - get_prop(G,v,:left))
    set_prop!(G,v,:edge_count,  1 + get_prop(G,v,:edge_count))
    c = get_prop(G,v,:center)
    e = get_prop(G,v,:edge_count)
    set_prop!(G,v,:center, c*((e-1)/e) + get_prop(G,v2,:center)*(1/e))
end

increment(s::BFS_state) = BFS_state(d=s.d+1,w=s.w,d_max=s.d_max)
decrement(s::BFS_state) = BFS_state(d=s.d-1,w=s.w,d_max=s.d_max)

function GraphPlottingBFS.bfs!(G,v,s)
    s = increment(s)
    if length(inneighbors(G,v)) == 0
        s = leaf_case!(G,v,s)
    else
        initial_branch_case!(G,v,s)
        for v2 in inneighbors(G,v)
            s = bfs!(G,v2,s)
            backup!(G,v,v2,s)
        end
    end
    return decrement(s)
end

# %% [markdown]
# # Setup Problem

# %% [markdown]
# ***
# The `project_spec` describes:
# 1. the inputs, outputs and process time of operations that must be performed at manufacturing stations
# 2. the dependencies between those operation (e.g. op 3 requires the outputs of op 1 and op 2

# %%
N = 120                  # num robots
M = 120                  # num delivery tasks
# project_spec = construct_random_project_spec(M;max_parents=3,depth_bias=1.0,Δt_min=0,Δt_max=0)
project_spec1 = construct_random_project_spec(Int(M/2);max_parents=3,depth_bias=0.25,Δt_min=0,Δt_max=0)
project_spec2 = construct_random_project_spec(Int(M/2);max_parents=3,depth_bias=0.25,Δt_min=0,Δt_max=0)
project_spec = combine_project_specs([project_spec1, project_spec2])
r₀,s₀,sₜ = initialize_random_2D_task_graph_env(N,M;d=[400,400])
Drs, Dss = cached_pickup_and_delivery_distances(r₀,s₀,sₜ)
plot_graph_bfs(project_spec.graph;mode=nothing,fillcolor="orange")
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Int64,Int64,Int64,Int64}(0, 0, 9, 27, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(3.69677cx, 25.4016cy), (4.30323cx, 25.0984cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(2.72cx, 21.5cy), (3.28cx, 21.5cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(2.72cx, 23.5cy), (3.28cx, 23.5cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(2.72cx, 22.5cy), (3.28cx, 22.5cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(3.69677cx, 24.5984cy), (4.30323cx, 24.9016cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.72cx, 14.5cy), (1.28cx, 14.5cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(1.72cx, 17.5cy), (2.28cx, 17.5cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(1.72cx, 18.5cy), (2.28cx, 18.5cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(2.69677cx, 20.4016cy), (3.30323cx, 20.0984cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(1.72cx, 19.5cy), (2.28cx, 19.5cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(1.65556cx, 16.3444cy), (2.34444cx, 15.6556cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(1.72cx, 15.5cy), (2.28cx, 15.5cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(2.632cx, 18.324cy), (3.368cx, 17.3427cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(3.69677cx, 22.4016cy), (4.30323cx, 22.0984cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(2.70871cx, 17.4304cy), (3.29129cx, 17.2362cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[ ...

# %% [markdown]
# ***
# The `delivery_graph` describes the delivery tasks that must be completed by robots in order to meet preconditions (objects 1 and 2 at station 3) for the prescribed operations

# %%
delivery_graph = construct_delivery_graph(project_spec,M)
G = delivery_graph.graph
# initialize vector of operation times
Δt = zeros(nv(G)) # Δt[j] is the wait time for the object j to appear once all inputs have been satisfied
for op in project_spec.operations
    for id in get_output_ids(op)
        Δt[id] = duration(op)
    end
end
plot_graph_bfs(delivery_graph.graph;mode=nothing)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Int64,Int64,Int64,Int64}(0, 0, 10, 59, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(8.52419cx, 50.8577cy), (9.47581cx, 42.2569cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(8.52419cx, 33.2187cy), (9.47581cx, 41.8195cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(7.54379cx, 55.7844cy), (8.45621cx, 51.292cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(7.54379cx, 46.3684cy), (8.45621cx, 50.8608cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(6.72cx, 46.1528cy), (7.28cx, 46.1528cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(5.55535cx, 49.7871cy), (6.44465cx, 46.3657cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(5.55535cx, 42.5185cy), (6.44465cx, 45.9399cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(6.72cx, 56.0cy), (7.28cx, 56.0cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(5.62203cx, 57.3169cy), (6.37797cx, 56.1831cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(5.62203cx, 54.6831cy), (6.37797cx, 55.8169cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(4.72cx, 54.5cy), (5.28cx, 54.5cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(4.55748cx, 45.7876cy), (5.44252cx, 42.5179cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(4.55748cx, 38.8235cy), (5.44252cx, 42.0932cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(3.55267cx, 42.4531cy), (4.44733cx, 38.8247cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{Tuple{Measure,Measure}}}(Compose.LinePrimitive{Tuple{Measure,Measure}}[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(3.71966cx, 38.6545cy), (4.28034cx, 38.6233cy)])], Symbol("")), Compose.Form{Compose.LinePrimitive{ ...

# %%
# set initial conditions
to0_ = Dict{Int,Float64}()
for v in vertices(G)
    if is_leaf_node(G,v)
        to0_[v] = 0.0
    end
end
tr0_ = Dict{Int,Float64}()
for i in 1:N
    tr0_[i] = 0.0
end

# %% [markdown]
# # Solve as MILP

# %%
model = formulate_JuMP_optimization_problem(G,Drs,Dss,Δt,to0_,tr0_,Gurobi.Optimizer;OutputFlag=0);
start_time = time()
optimize!(model)
solve_time = time() - start_time
optimal = (termination_status(model) == MathOptInterface.TerminationStatusCode(1))
@show solve_time
@show optimal;
assignment = Matrix{Int}(value.(model[:x]));
# Out:
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# solve_time = 1.7992699146270752
# optimal = true

# %%
r_frontier = Set{Int}(collect(1:N))
t_frontier = Set{Int}()
for j in 1:M
    if is_leaf_node(G,j)
        i = findfirst(assignment[:,j] .== 1)
        if i <= N
            push!(t_frontier, j)
#             push!(r_frontier, i)
        end
    end
end
length(t_frontier)
while length(t_frontier) > 0
    j = pop!(t_frontier) # task id
    for j2 in inneighbors(G,j) # parent tasks
        cache.to0[j] = max(cache.to0[j], cache.tof[j2] + Δt[j])
    end
    i = findfirst(cache.x[:,j] .== 1) # robot id
    if i in r_frontier
        tro0 = cache.tr0[i] + Drs[i,j] # robot arrival time
        cache.tof[j] = max(cache.to0[j], tro0) + Dss[j,j] # task completion time
        cache.tr0[j+N] = cache.tof[j] # new robot availability time
        push!(r_frontier, i+N)
    end
end
# Out:
# 57

# %%
spec = TaskGraphProblemSpec(N,M,G,Drs,Dss,Δt,tr0_,to0_)
bfs_traversal = get_bfs_traversal(G);
cache = SearchCache(N,M,to0_,tr0_)
for j in 1:M
    i = findfirst(assignment[:,j] .== 1)
    cache.x[i,j] = 1
end
cache = process_solution(cache,spec,bfs_traversal);
# Out:
# v = 1
# xi = findfirst(cache.x[:, v] .== 1) = 98
# tro0 = cache.tr0[xi] + Drs[xi, v] = 32.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 196.0
# cache.tr0[v + N] = cache.tof[v] = 196.0
# v = 2
# xi = findfirst(cache.x[:, v] .== 1) = 12
# tro0 = cache.tr0[xi] + Drs[xi, v] = 25.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 471.0
# cache.tr0[v + N] = cache.tof[v] = 471.0
# v = 3
# xi = findfirst(cache.x[:, v] .== 1) = 113
# tro0 = cache.tr0[xi] + Drs[xi, v] = 25.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 423.0
# cache.tr0[v + N] = cache.tof[v] = 423.0
# v = 4
# xi = findfirst(cache.x[:, v] .== 1) = 73
# tro0 = cache.tr0[xi] + Drs[xi, v] = 22.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 95.0
# cache.tr0[v + N] = cache.tof[v] = 95.0
# v = 21
# xi = findfirst(cache.x[:, v] .== 1) = 47
# tro0 = cache.tr0[xi] + Drs[xi, v] = 10.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 326.0
# cache.tr0[v + N] = cache.tof[v] = 326.0
# v = 22
# xi = findfirst(cache.x[:, v] .== 1) = 86
# tro0 = cache.tr0[xi] + Drs[xi, v] = 88.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 371.0
# cache.tr0[v + N] = cache.tof[v] = 371.0
# v = 8
# xi = findfirst(cache.x[:, v] .== 1) = 29
# tro0 = cache.tr0[xi] + Drs[xi, v] = 34.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 235.0
# cache.tr0[v + N] = cache.tof[v] = 235.0
# v = 9
# xi = findfirst(cache.x[:, v] .== 1) = 20
# tro0 = cache.tr0[xi] + Drs[xi, v] = 6.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 182.0
# cache.tr0[v + N] = cache.tof[v] = 182.0
# v = 14
# xi = findfirst(cache.x[:, v] .== 1) = 7
# tro0 = cache.tr0[xi] + Drs[xi, v] = 37.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 304.0
# cache.tr0[v + N] = cache.tof[v] = 304.0
# v = 15
# xi = findfirst(cache.x[:, v] .== 1) = 69
# tro0 = cache.tr0[xi] + Drs[xi, v] = 6.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 306.0
# cache.tr0[v + N] = cache.tof[v] = 306.0
# v = 5
# xi = findfirst(cache.x[:, v] .== 1) = 52
# tro0 = cache.tr0[xi] + Drs[xi, v] = 25.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 374.0
# cache.tr0[v + N] = cache.tof[v] = 374.0
# v = 6
# xi = findfirst(cache.x[:, v] .== 1) = 15
# tro0 = cache.tr0[xi] + Drs[xi, v] = 21.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 213.0
# cache.tr0[v + N] = cache.tof[v] = 213.0
# v = 7
# xi = findfirst(cache.x[:, v] .== 1) = 3
# tro0 = cache.tr0[xi] + Drs[xi, v] = 59.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 208.0
# cache.tr0[v + N] = cache.tof[v] = 208.0
# v = 10
# xi = findfirst(cache.x[:, v] .== 1) = 107
# tro0 = cache.tr0[xi] + Drs[xi, v] = 26.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 209.0
# cache.tr0[v + N] = cache.tof[v] = 209.0
# v = 11
# xi = findfirst(cache.x[:, v] .== 1) = 79
# tro0 = cache.tr0[xi] + Drs[xi, v] = 14.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 57.0
# cache.tr0[v + N] = cache.tof[v] = 57.0
# v = 12
# xi = findfirst(cache.x[:, v] .== 1) = 118
# tro0 = cache.tr0[xi] + Drs[xi, v] = 5.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 568.0
# cache.tr0[v + N] = cache.tof[v] = 568.0
# v = 25
# xi = findfirst(cache.x[:, v] .== 1) = 59
# tro0 = cache.tr0[xi] + Drs[xi, v] = 37.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 530.0
# cache.tr0[v + N] = cache.tof[v] = 530.0
# v = 26
# xi = findfirst(cache.x[:, v] .== 1) = 33
# tro0 = cache.tr0[xi] + Drs[xi, v] = 48.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 324.0
# cache.tr0[v + N] = cache.tof[v] = 324.0
# v = 16
# xi = findfirst(cache.x[:, v] .== 1) = 80
# tro0 = cache.tr0[xi] + Drs[xi, v] = 38.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 395.0
# cache.tr0[v + N] = cache.tof[v] = 395.0
# v = 17
# xi = findfirst(cache.x[:, v] .== 1) = 84
# tro0 = cache.tr0[xi] + Drs[xi, v] = 28.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 314.0
# cache.tr0[v + N] = cache.tof[v] = 314.0
# v = 23
# xi = findfirst(cache.x[:, v] .== 1) = 21
# tro0 = cache.tr0[xi] + Drs[xi, v] = 31.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 233.0
# cache.tr0[v + N] = cache.tof[v] = 233.0
# v = 24
# xi = findfirst(cache.x[:, v] .== 1) = 30
# tro0 = cache.tr0[xi] + Drs[xi, v] = 30.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 502.0
# cache.tr0[v + N] = cache.tof[v] = 502.0
# v = 27
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 196.0
# xi = findfirst(cache.x[:, v] .== 1) = 102
# tro0 = cache.tr0[xi] + Drs[xi, v] = 174.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 495.0
# cache.tr0[v + N] = cache.tof[v] = 495.0
# v = 13
# xi = findfirst(cache.x[:, v] .== 1) = 116
# tro0 = cache.tr0[xi] + Drs[xi, v] = 41.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 281.0
# cache.tr0[v + N] = cache.tof[v] = 281.0
# v = 29
# xi = findfirst(cache.x[:, v] .== 1) = 14
# tro0 = cache.tr0[xi] + Drs[xi, v] = 15.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 89.0
# cache.tr0[v + N] = cache.tof[v] = 89.0
# v = 30
# xi = findfirst(cache.x[:, v] .== 1) = 49
# tro0 = cache.tr0[xi] + Drs[xi, v] = 125.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 296.0
# cache.tr0[v + N] = cache.tof[v] = 296.0
# v = 31
# xi = findfirst(cache.x[:, v] .== 1) = 48
# tro0 = cache.tr0[xi] + Drs[xi, v] = 30.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 123.0
# cache.tr0[v + N] = cache.tof[v] = 123.0
# v = 28
# xi = findfirst(cache.x[:, v] .== 1) = 112
# tro0 = cache.tr0[xi] + Drs[xi, v] = 47.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 239.0
# cache.tr0[v + N] = cache.tof[v] = 239.0
# v = 35
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 304.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 306.0
# xi = findfirst(cache.x[:, v] .== 1) = 104
# tro0 = cache.tr0[xi] + Drs[xi, v] = 200.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 634.0
# cache.tr0[v + N] = cache.tof[v] = 634.0
# v = 36
# xi = findfirst(cache.x[:, v] .== 1) = 93
# tro0 = cache.tr0[xi] + Drs[xi, v] = 187.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 619.0
# cache.tr0[v + N] = cache.tof[v] = 619.0
# v = 37
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 374.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 374.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 374.0
# xi = findfirst(cache.x[:, v] .== 1) = 2
# tro0 = cache.tr0[xi] + Drs[xi, v] = 299.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 636.0
# cache.tr0[v + N] = cache.tof[v] = 636.0
# v = 38
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 209.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 209.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 568.0
# xi = findfirst(cache.x[:, v] .== 1) = 10
# tro0 = cache.tr0[xi] + Drs[xi, v] = 238.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1098.0
# cache.tr0[v + N] = cache.tof[v] = 1098.0
# v = 39
# xi = findfirst(cache.x[:, v] .== 1) = 19
# tro0 = cache.tr0[xi] + Drs[xi, v] = 27.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 231.0
# cache.tr0[v + N] = cache.tof[v] = 231.0
# v = 40
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 530.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 530.0
# xi = findfirst(cache.x[:, v] .== 1) = 11
# tro0 = cache.tr0[xi] + Drs[xi, v] = 360.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 851.0
# cache.tr0[v + N] = cache.tof[v] = 851.0
# v = 41
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 395.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 395.0
# xi = findfirst(cache.x[:, v] .== 1) = 13
# tro0 = cache.tr0[xi] + Drs[xi, v] = 358.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 690.0
# cache.tr0[v + N] = cache.tof[v] = 690.0
# v = 18
# xi = findfirst(cache.x[:, v] .== 1) = 105
# tro0 = cache.tr0[xi] + Drs[xi, v] = 148.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 461.0
# cache.tr0[v + N] = cache.tof[v] = 461.0
# v = 19
# xi = findfirst(cache.x[:, v] .== 1) = 60
# tro0 = cache.tr0[xi] + Drs[xi, v] = 23.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 405.0
# cache.tr0[v + N] = cache.tof[v] = 405.0
# v = 20
# xi = findfirst(cache.x[:, v] .== 1) = 51
# tro0 = cache.tr0[xi] + Drs[xi, v] = 95.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 495.0
# cache.tr0[v + N] = cache.tof[v] = 495.0
# v = 43
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 495.0
# xi = findfirst(cache.x[:, v] .== 1) = 18
# tro0 = cache.tr0[xi] + Drs[xi, v] = 293.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 826.0
# cache.tr0[v + N] = cache.tof[v] = 826.0
# v = 44
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 281.0
# xi = findfirst(cache.x[:, v] .== 1) = 121
# tro0 = cache.tr0[xi] + Drs[xi, v] = 240.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 538.0
# cache.tr0[v + N] = cache.tof[v] = 538.0
# v = 45
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 89.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 296.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 296.0
# xi = findfirst(cache.x[:, v] .== 1) = 25
# tro0 = cache.tr0[xi] + Drs[xi, v] = 139.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 753.0
# cache.tr0[v + N] = cache.tof[v] = 753.0
# v = 48
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1098.0
# xi = findfirst(cache.x[:, v] .== 1) = 24
# tro0 = cache.tr0[xi] + Drs[xi, v] = 392.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1329.0
# cache.tr0[v + N] = cache.tof[v] = 1329.0
# v = 49
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 231.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 851.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 851.0
# xi = findfirst(cache.x[:, v] .== 1) = 26
# tro0 = cache.tr0[xi] + Drs[xi, v] = 293.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1141.0
# cache.tr0[v + N] = cache.tof[v] = 1141.0
# v = 50
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 461.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 461.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 495.0
# xi = findfirst(cache.x[:, v] .== 1) = 27
# tro0 = cache.tr0[xi] + Drs[xi, v] = 316.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 761.0
# cache.tr0[v + N] = cache.tof[v] = 761.0
# v = 32
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 471.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 471.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 471.0
# xi = findfirst(cache.x[:, v] .== 1) = 5
# tro0 = cache.tr0[xi] + Drs[xi, v] = 165.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 939.0
# cache.tr0[v + N] = cache.tof[v] = 939.0
# v = 33
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 326.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 371.0
# xi = findfirst(cache.x[:, v] .== 1) = 159
# tro0 = cache.tr0[xi] + Drs[xi, v] = 336.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 615.0
# cache.tr0[v + N] = cache.tof[v] = 615.0
# v = 34
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 235.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 235.0
# xi = findfirst(cache.x[:, v] .== 1) = 8
# tro0 = cache.tr0[xi] + Drs[xi, v] = 175.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 371.0
# cache.tr0[v + N] = cache.tof[v] = 371.0
# v = 51
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 826.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 826.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 826.0
# xi = findfirst(cache.x[:, v] .== 1) = 28
# tro0 = cache.tr0[xi] + Drs[xi, v] = 224.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 987.0
# cache.tr0[v + N] = cache.tof[v] = 987.0
# v = 52
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1329.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1329.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1329.0
# xi = findfirst(cache.x[:, v] .== 1) = 32
# tro0 = cache.tr0[xi] + Drs[xi, v] = 188.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1773.0
# cache.tr0[v + N] = cache.tof[v] = 1773.0
# v = 42
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 233.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 502.0
# xi = findfirst(cache.x[:, v] .== 1) = 94
# tro0 = cache.tr0[xi] + Drs[xi, v] = 265.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 572.0
# cache.tr0[v + N] = cache.tof[v] = 572.0
# v = 53
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 939.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 939.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 939.0
# xi = findfirst(cache.x[:, v] .== 1) = 34
# tro0 = cache.tr0[xi] + Drs[xi, v] = 197.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1387.0
# cache.tr0[v + N] = cache.tof[v] = 1387.0
# v = 54
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 987.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1773.0
# xi = findfirst(cache.x[:, v] .== 1) = 210
# tro0 = cache.tr0[xi] + Drs[xi, v] = Inf
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 47
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 634.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 634.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 636.0
# xi = findfirst(cache.x[:, v] .== 1) = 115
# tro0 = cache.tr0[xi] + Drs[xi, v] = 84.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 770.0
# cache.tr0[v + N] = cache.tof[v] = 770.0
# v = 46
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 239.0
# xi = findfirst(cache.x[:, v] .== 1) = 23
# tro0 = cache.tr0[xi] + Drs[xi, v] = 151.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 712.0
# cache.tr0[v + N] = cache.tof[v] = 712.0
# v = 55
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 572.0
# xi = findfirst(cache.x[:, v] .== 1) = 36
# tro0 = cache.tr0[xi] + Drs[xi, v] = 500.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 909.0
# cache.tr0[v + N] = cache.tof[v] = 909.0
# v = 56
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1387.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 37
# tro0 = cache.tr0[xi] + Drs[xi, v] = 366.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 57
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 770.0
# xi = findfirst(cache.x[:, v] .== 1) = 38
# tro0 = cache.tr0[xi] + Drs[xi, v] = 379.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 879.0
# cache.tr0[v + N] = cache.tof[v] = 879.0
# v = 58
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 712.0
# xi = findfirst(cache.x[:, v] .== 1) = 39
# tro0 = cache.tr0[xi] + Drs[xi, v] = 129.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 831.0
# cache.tr0[v + N] = cache.tof[v] = 831.0
# v = 59
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 909.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 40
# tro0 = cache.tr0[xi] + Drs[xi, v] = 195.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 60
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 879.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 879.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 41
# tro0 = cache.tr0[xi] + Drs[xi, v] = 338.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 74
# xi = findfirst(cache.x[:, v] .== 1) = 111
# tro0 = cache.tr0[xi] + Drs[xi, v] = 111.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 761.0
# cache.tr0[v + N] = cache.tof[v] = 761.0
# v = 75
# xi = findfirst(cache.x[:, v] .== 1) = 95
# tro0 = cache.tr0[xi] + Drs[xi, v] = 133.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 513.0
# cache.tr0[v + N] = cache.tof[v] = 513.0
# v = 68
# xi = findfirst(cache.x[:, v] .== 1) = 17
# tro0 = cache.tr0[xi] + Drs[xi, v] = 9.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 290.0
# cache.tr0[v + N] = cache.tof[v] = 290.0
# v = 69
# xi = findfirst(cache.x[:, v] .== 1) = 4
# tro0 = cache.tr0[xi] + Drs[xi, v] = 55.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 230.0
# cache.tr0[v + N] = cache.tof[v] = 230.0
# v = 73
# xi = findfirst(cache.x[:, v] .== 1) = 88
# tro0 = cache.tr0[xi] + Drs[xi, v] = 20.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 184.0
# cache.tr0[v + N] = cache.tof[v] = 184.0
# v = 71
# xi = findfirst(cache.x[:, v] .== 1) = 96
# tro0 = cache.tr0[xi] + Drs[xi, v] = 54.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 496.0
# cache.tr0[v + N] = cache.tof[v] = 496.0
# v = 72
# xi = findfirst(cache.x[:, v] .== 1) = 22
# tro0 = cache.tr0[xi] + Drs[xi, v] = 79.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 454.0
# cache.tr0[v + N] = cache.tof[v] = 454.0
# v = 64
# xi = findfirst(cache.x[:, v] .== 1) = 120
# tro0 = cache.tr0[xi] + Drs[xi, v] = 87.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 174.0
# cache.tr0[v + N] = cache.tof[v] = 174.0
# v = 65
# xi = findfirst(cache.x[:, v] .== 1) = 76
# tro0 = cache.tr0[xi] + Drs[xi, v] = 58.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 429.0
# cache.tr0[v + N] = cache.tof[v] = 429.0
# v = 66
# xi = findfirst(cache.x[:, v] .== 1) = 16
# tro0 = cache.tr0[xi] + Drs[xi, v] = 24.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 120.0
# cache.tr0[v + N] = cache.tof[v] = 120.0
# v = 77
# xi = findfirst(cache.x[:, v] .== 1) = 200
# tro0 = cache.tr0[xi] + Drs[xi, v] = Inf
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 67
# xi = findfirst(cache.x[:, v] .== 1) = 114
# tro0 = cache.tr0[xi] + Drs[xi, v] = 266.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 706.0
# cache.tr0[v + N] = cache.tof[v] = 706.0
# v = 79
# xi = findfirst(cache.x[:, v] .== 1) = 6
# tro0 = cache.tr0[xi] + Drs[xi, v] = 22.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 442.0
# cache.tr0[v + N] = cache.tof[v] = 442.0
# v = 80
# xi = findfirst(cache.x[:, v] .== 1) = 64
# tro0 = cache.tr0[xi] + Drs[xi, v] = 10.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 85.0
# cache.tr0[v + N] = cache.tof[v] = 85.0
# v = 81
# xi = findfirst(cache.x[:, v] .== 1) = 31
# tro0 = cache.tr0[xi] + Drs[xi, v] = 76.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 415.0
# cache.tr0[v + N] = cache.tof[v] = 415.0
# v = 89
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 496.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 496.0
# xi = findfirst(cache.x[:, v] .== 1) = 45
# tro0 = cache.tr0[xi] + Drs[xi, v] = 144.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 760.0
# cache.tr0[v + N] = cache.tof[v] = 760.0
# v = 78
# xi = findfirst(cache.x[:, v] .== 1) = 35
# tro0 = cache.tr0[xi] + Drs[xi, v] = 44.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 235.0
# cache.tr0[v + N] = cache.tof[v] = 235.0
# v = 61
# xi = findfirst(cache.x[:, v] .== 1) = 97
# tro0 = cache.tr0[xi] + Drs[xi, v] = 67.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 513.0
# cache.tr0[v + N] = cache.tof[v] = 513.0
# v = 62
# xi = findfirst(cache.x[:, v] .== 1) = 78
# tro0 = cache.tr0[xi] + Drs[xi, v] = 7.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 142.0
# cache.tr0[v + N] = cache.tof[v] = 142.0
# v = 63
# xi = findfirst(cache.x[:, v] .== 1) = 103
# tro0 = cache.tr0[xi] + Drs[xi, v] = 65.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 349.0
# cache.tr0[v + N] = cache.tof[v] = 349.0
# v = 70
# xi = findfirst(cache.x[:, v] .== 1) = 99
# tro0 = cache.tr0[xi] + Drs[xi, v] = 26.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 167.0
# cache.tr0[v + N] = cache.tof[v] = 167.0
# v = 90
# xi = findfirst(cache.x[:, v] .== 1) = 9
# tro0 = cache.tr0[xi] + Drs[xi, v] = 18.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 258.0
# cache.tr0[v + N] = cache.tof[v] = 258.0
# v = 91
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 174.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 429.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 429.0
# xi = findfirst(cache.x[:, v] .== 1) = 44
# tro0 = cache.tr0[xi] + Drs[xi, v] = 127.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 647.0
# cache.tr0[v + N] = cache.tof[v] = 647.0
# v = 85
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 290.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 290.0
# xi = findfirst(cache.x[:, v] .== 1) = 46
# tro0 = cache.tr0[xi] + Drs[xi, v] = 64.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 737.0
# cache.tr0[v + N] = cache.tof[v] = 737.0
# v = 76
# xi = findfirst(cache.x[:, v] .== 1) = 42
# tro0 = cache.tr0[xi] + Drs[xi, v] = 58.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 111.0
# cache.tr0[v + N] = cache.tof[v] = 111.0
# v = 92
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 196
# tro0 = cache.tr0[xi] + Drs[xi, v] = 299.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 86
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 184.0
# xi = findfirst(cache.x[:, v] .== 1) = 54
# tro0 = cache.tr0[xi] + Drs[xi, v] = 163.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 464.0
# cache.tr0[v + N] = cache.tof[v] = 464.0
# v = 94
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 442.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 442.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 442.0
# xi = findfirst(cache.x[:, v] .== 1) = 53
# tro0 = cache.tr0[xi] + Drs[xi, v] = 161.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 911.0
# cache.tr0[v + N] = cache.tof[v] = 911.0
# v = 95
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 760.0
# xi = findfirst(cache.x[:, v] .== 1) = 56
# tro0 = cache.tr0[xi] + Drs[xi, v] = 339.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 830.0
# cache.tr0[v + N] = cache.tof[v] = 830.0
# v = 96
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 235.0
# xi = findfirst(cache.x[:, v] .== 1) = 57
# tro0 = cache.tr0[xi] + Drs[xi, v] = 42.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 725.0
# cache.tr0[v + N] = cache.tof[v] = 725.0
# v = 82
# xi = findfirst(cache.x[:, v] .== 1) = 119
# tro0 = cache.tr0[xi] + Drs[xi, v] = 173.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 562.0
# cache.tr0[v + N] = cache.tof[v] = 562.0
# v = 83
# xi = findfirst(cache.x[:, v] .== 1) = 131
# tro0 = cache.tr0[xi] + Drs[xi, v] = 292.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 641.0
# cache.tr0[v + N] = cache.tof[v] = 641.0
# v = 84
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 761.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 761.0
# xi = findfirst(cache.x[:, v] .== 1) = 43
# tro0 = cache.tr0[xi] + Drs[xi, v] = 437.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 934.0
# cache.tr0[v + N] = cache.tof[v] = 934.0
# v = 104
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 464.0
# xi = findfirst(cache.x[:, v] .== 1) = 65
# tro0 = cache.tr0[xi] + Drs[xi, v] = 115.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 915.0
# cache.tr0[v + N] = cache.tof[v] = 915.0
# v = 105
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 911.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 911.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 911.0
# xi = findfirst(cache.x[:, v] .== 1) = 66
# tro0 = cache.tr0[xi] + Drs[xi, v] = 373.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1468.0
# cache.tr0[v + N] = cache.tof[v] = 1468.0
# v = 106
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 562.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 641.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 934.0
# xi = findfirst(cache.x[:, v] .== 1) = 67
# tro0 = cache.tr0[xi] + Drs[xi, v] = 306.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1309.0
# cache.tr0[v + N] = cache.tof[v] = 1309.0
# v = 102
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 111.0
# xi = findfirst(cache.x[:, v] .== 1) = 110
# tro0 = cache.tr0[xi] + Drs[xi, v] = 34.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 147.0
# cache.tr0[v + N] = cache.tof[v] = 147.0
# v = 103
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 62
# tro0 = cache.tr0[xi] + Drs[xi, v] = 261.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 93
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 706.0
# xi = findfirst(cache.x[:, v] .== 1) = 50
# tro0 = cache.tr0[xi] + Drs[xi, v] = 391.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1079.0
# cache.tr0[v + N] = cache.tof[v] = 1079.0
# v = 109
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1079.0
# xi = findfirst(cache.x[:, v] .== 1) = 71
# tro0 = cache.tr0[xi] + Drs[xi, v] = 404.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1270.0
# cache.tr0[v + N] = cache.tof[v] = 1270.0
# v = 97
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 513.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 513.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 513.0
# xi = findfirst(cache.x[:, v] .== 1) = 58
# tro0 = cache.tr0[xi] + Drs[xi, v] = 102.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 919.0
# cache.tr0[v + N] = cache.tof[v] = 919.0
# v = 98
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 167.0
# xi = findfirst(cache.x[:, v] .== 1) = 63
# tro0 = cache.tr0[xi] + Drs[xi, v] = 90.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 467.0
# cache.tr0[v + N] = cache.tof[v] = 467.0
# v = 110
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1270.0
# xi = findfirst(cache.x[:, v] .== 1) = 72
# tro0 = cache.tr0[xi] + Drs[xi, v] = 449.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1490.0
# cache.tr0[v + N] = cache.tof[v] = 1490.0
# v = 111
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 919.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 919.0
# xi = findfirst(cache.x[:, v] .== 1) = 74
# tro0 = cache.tr0[xi] + Drs[xi, v] = 337.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1400.0
# cache.tr0[v + N] = cache.tof[v] = 1400.0
# v = 107
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 915.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1468.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1468.0
# xi = findfirst(cache.x[:, v] .== 1) = 68
# tro0 = cache.tr0[xi] + Drs[xi, v] = 114.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1887.0
# cache.tr0[v + N] = cache.tof[v] = 1887.0
# v = 108
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 147.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 70
# tro0 = cache.tr0[xi] + Drs[xi, v] = 281.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 99
# xi = findfirst(cache.x[:, v] .== 1) = 55
# tro0 = cache.tr0[xi] + Drs[xi, v] = 18.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 71.0
# cache.tr0[v + N] = cache.tof[v] = 71.0
# v = 100
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 258.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 647.0
# xi = findfirst(cache.x[:, v] .== 1) = 135
# tro0 = cache.tr0[xi] + Drs[xi, v] = 594.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 845.0
# cache.tr0[v + N] = cache.tof[v] = 845.0
# v = 101
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 737.0
# xi = findfirst(cache.x[:, v] .== 1) = 61
# tro0 = cache.tr0[xi] + Drs[xi, v] = 139.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1107.0
# cache.tr0[v + N] = cache.tof[v] = 1107.0
# v = 113
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1887.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 77
# tro0 = cache.tr0[xi] + Drs[xi, v] = 304.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 114
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 71.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 845.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1107.0
# xi = findfirst(cache.x[:, v] .== 1) = 100
# tro0 = cache.tr0[xi] + Drs[xi, v] = 347.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1337.0
# cache.tr0[v + N] = cache.tof[v] = 1337.0
# v = 115
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 81
# tro0 = cache.tr0[xi] + Drs[xi, v] = 445.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 112
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1490.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1490.0
# xi = findfirst(cache.x[:, v] .== 1) = 75
# tro0 = cache.tr0[xi] + Drs[xi, v] = 202.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 1937.0
# cache.tr0[v + N] = cache.tof[v] = 1937.0
# v = 87
# xi = findfirst(cache.x[:, v] .== 1) = 83
# tro0 = cache.tr0[xi] + Drs[xi, v] = 13.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 194.0
# cache.tr0[v + N] = cache.tof[v] = 194.0
# v = 88
# xi = findfirst(cache.x[:, v] .== 1) = 108
# tro0 = cache.tr0[xi] + Drs[xi, v] = 48.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 381.0
# cache.tr0[v + N] = cache.tof[v] = 381.0
# v = 116
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 82
# tro0 = cache.tr0[xi] + Drs[xi, v] = 150.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 117
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 1937.0
# xi = findfirst(cache.x[:, v] .== 1) = 85
# tro0 = cache.tr0[xi] + Drs[xi, v] = 232.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 2096.0
# cache.tr0[v + N] = cache.tof[v] = 2096.0
# v = 118
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 194.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 381.0
# xi = findfirst(cache.x[:, v] .== 1) = 149
# tro0 = cache.tr0[xi] + Drs[xi, v] = 226.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = 735.0
# cache.tr0[v + N] = cache.tof[v] = 735.0
# v = 119
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 87
# tro0 = cache.tr0[xi] + Drs[xi, v] = 238.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf
# v = 120
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = 735.0
# cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v]) = Inf
# xi = findfirst(cache.x[:, v] .== 1) = 89
# tro0 = cache.tr0[xi] + Drs[xi, v] = 374.0
# cache.tof[v] = max(cache.to0[v], tro0) + Dss[v, v] = Inf
# cache.tr0[v + N] = cache.tof[v] = Inf

# %%
function TaskGraphs.process_solution(cache::SearchCache,spec::TaskGraphProblemSpec,bfs_traversal)
    Drs, Dss, Δt, N, G = spec.Drs, spec.Dss, spec.Δt, spec.N, spec.graph
    # Compute Lower Bounds Via Forward Dynamic Programming pass
    for v in bfs_traversal
        @show v
        for v2 in inneighbors(G,v)
            @show cache.to0[v] = max(cache.to0[v], cache.tof[v2] + Δt[v])
        end
        @show xi = findfirst(cache.x[:,v] .== 1)
        @show tro0 = cache.tr0[xi] + Drs[xi,v]
        @show cache.tof[v] = max(cache.to0[v], tro0) + Dss[v,v]
        @show cache.tr0[v+N] = cache.tof[v]
    end
    # Compute Slack Via Backward Dynamic Programming pass
    for v in reverse(bfs_traversal)
        for v2 in inneighbors(G,v)
            cache.local_slack[v2] = cache.to0[v] - cache.tof[v2]
            cache.slack[v2]       = cache.slack[v] + cache.local_slack[v2]
        end
    end
    cache
end

# %% [markdown]
# # Solve assignment problem with Dynamic Programming
#
# Two possible search paradigms:
# 1. Start with the lower bound infeasible solution, then add constraints via branch-and-bound until the first feasible (and therefore the optimal) solution is returned. One major issue with this approach is that it may take a VERY long time to get through all of the low-cost but infeasible solutions.
# 2. Start with a greedy solution and improve it until it can't be improved anymore. This paradigm comes with two questions: (a) How to know that a solution can't be improved? (b) How to guarantee global optimality (e.g. how to start in the right "basin of attraction")?
#
# I think it would be good to start tracking the slack associated with dummy robots as well

# %%
start_time = time()
cache, FEASIBLE = solve_task_graphs_problem(G,Drs,Dss,Δt,to0_,tr0_;mode=1,MAX_ITERS=100000)
solve_time = time() - start_time

@show solve_time 
@show cache.tof
@show cache.slack
@show cache.local_slack;

# %% [markdown]
# # MATROID SEARCH!!!!!!!
#
# 1. First lesson learned: the dimensionality of the matroid table scales exponentially with problem size. I will have to use a sparse lookup table.

# %%
function get_matroid_table_dimension(n::Int)
    N = 2^n
end

# %%
struct AssignmentSeries
    robot::Int
    tasks::Vector{Int}
end
struct PartialAssignment
    assignments::Set{AssignmentSeries}
end
struct SearchState
    robot_x::Vector{Int} # indices giving robot locations
    robot_t::Vector{Float64} # indices giving robot availability times
    assignments::Vector{AssignmentSeries}
end
struct AssignmentMatroid
    robots::Set{Int}
    tasks::Set{Int}
end
const SearchTable = Dict{Int,Vector{AssignmentSeries}}
function SearchTable(N::Int)
    SearchTable( i => Vector{AssignmentSeries}() for i in 1:N)
end
const AssignmentQueues = Dict{Int,PriorityQueue{AssignmentSeries,Float64}}
function AssignmentQueues(M::Int)
    AssignmentQueues(j=>PriorityQueue{AssignmentSeries,Float64}() for j in 1:M)
end

# %%
# assignment_queues = AssignmentQueues(M)
# for j in 1:M
#     q = assignment_queues[j]
#     if is_leaf_node(G,j)
#         for i in 1:N
#             assignment = AssignmentSeries(i,[j])
#             tof = max(to0_[j], tr0_[i] + Drs[i,j]) + Dss[j,j]
#             enqueue!(q,assignment=>tof)
#         end
#     end
# end

# %%
# n = 4; m = 7
# N = get_matroid_table_dimension(n)
# M = get_matroid_table_dimension(m)
# search_table = SearchTable(n)

# %% [markdown]
# # Sandbox

# %%
bfs_traversal = get_bfs_node_traversal(G);
cache = SearchCache(N,M,to0_,tr0_)
for j in 1:M
    upstream_jobs = [j, map(e->e.dst,collect(edges(bfs_tree(G,j;dir=:in))))...]
    for v in upstream_jobs
        add_constraint!(cache.FT, j+N, v)
    end
end
spec = TaskGraphProblemSpec(N,M,Drs,Dss,tr0_,to0_)

cache = solve_task_graph(cache,spec,bfs_traversal)

# %%
stacked_vals = [cache.tr0;cache.to0;cache.tof;cache.slack]
for j in 1:M
    cache = deepcopy(cache)
    for i in 1:N+M
        if cache.x[i] == 1
            add_constraint!(cache.FT, i, j)
        end
    end
    cache = solve_task_graph(cache,spec,bfs_traversal)
    stacked_vals = hcat(stacked_vals, [cache.tr0;cache.to0;cache.tof;cache.slack])
end
stacked_vals

# %%
cache.FT.arr

# %%
j = 1
idxs = findall(cache.x[j,:] .== 1)
ordering = (cache.slack .* cache.x[j,:])[idxs]
sorted_idxs = sort(idxs, by=i->(cache.slack .* cache.x[j,:])[i])
@show idxs
@show ordering
@show sorted_idxs;

# %%
cr_path = get_critical_path(bfs_traversal,slack)
@show slack
@show local_slack
@show cr_path
plot_graph_bfs(delivery_graph.graph;mode=nothing)

# %% [markdown]
# # Comparisons

# %%
N = 5                  # num robots
M = 10                 # num delivery tasks
r₀,s₀,sₜ = initialize_random_2D_task_graph_env(N,M;d=[40,40])
Drs, Dss = cached_pickup_and_delivery_distances(r₀,s₀,sₜ)
project_spec = construct_random_project_spec(M;max_parents=3,depth_bias=1.0,Δt_min=0,Δt_max=0)

delivery_graph = construct_delivery_graph(project_spec,M)
G = delivery_graph.graph
# initialize vector of operation times
Δt = zeros(nv(G)) # Δt[j] is the wait time for the object j to appear once all inputs have been satisfied
for op in project_spec.operations
    for id in get_output_ids(op)
        Δt[id] = duration(op)
    end
end

# set initial conditions
to0_ = Dict{Int,Float64}()
for v in vertices(G)
    if is_leaf_node(G,v)
        to0_[v] = 0.0
    end
end
tr0_ = Dict{Int,Float64}()
for i in 1:N
    tr0_[i] = 0.0
end
# plot_graph_bfs(delivery_graph.graph;mode=nothing)

# %% [markdown]
# # Sandbox

# %%
# @show backward_slack;
########### Compute Greedy Solution ###########
# sorted lists of assignment time
A = Vector{Vector{Int}}() #[collect(1:N+M) for j in 1:M])
D_ = Drs .+ tr0_low
for j in 1:M
    push!(A, sortperm(Drs[:,j]+tr0_low)) # sort robot ids by lower bound on arrival time
    D_[:,j] = D_[:,j] .- Drs[A[j][1],j]
end
# ### Try to find an optimal assignment working forward
# Push open nodes into a priority queue, where priority is defined by slack
p = PriorityQueue{Int,Float64}()
for v in vertices(G)
    if is_leaf_node(G,v)
        enqueue!(p,v=>slack[v])
    end
end
# Iteratively compute assignments by moving through the graph from the bottom up
x = Dict{Int,Int}() # j=>i maps task j => robot i
assigned = Set{Int}()
# While an optimal solution has not yet been returned
while length(p) > 0
    # Pop an open node from the queue and make an assignment (greedy vs. selfless...)
    j, dt = dequeue_pair!(p)
    # find the best robot for the job
    for i in A[j]
        
    end
    a = A[j]
    d = Int.(round.(D_[:,j][A[j]]))
    @show j
    @show a
    @show d
end
#     1. If the greedy assignment is already taken and the next assignment maintains non-negative slack, continue to the next assignment.
#     2. If the greedy assignment maintains the current critical path, keep it
#     3. If the greedy assignment ... 
#     4. return to 2

# %%
bfs_traversal = bfs_tree(G,M;dir=:in)
ids = map(e->e.dst, collect(edges(bfs_traversal)))
p = PriorityQueue{Int,Float64}()
for v in vertices(G)
    if is_leaf_node(G,v)
        enqueue!(p,v=>slack[v])
    end
end

# %% [markdown]
# # Next steps:
#
# - How to solve the planning problem? I have a vague idea for a
#   forward-backward BFS algorithm with pruning.
# - It may be helpful to compute the slack in both directions
# - When lots of projects are happening in the factory at once, this will
#   converge to a sort of steady-state thing. How to formulate this on a
#   receding horizon basis? Initial thoughts: problem statement is defined
#   by available time of robots (0 for robots with no payload, scheduled
#   dropoff time for robots with a payload), graph(s), distance matrix and
#   process time vector $\Delta t$. Also, the right approach for massive
#   scaling may be a prioritized planning approach.

# %%
assignments = Dict{Int,Int}() # j=>i maps task j => robot i
while length(p) > 0
    j, dt = dequeue_pair!(p)
end
